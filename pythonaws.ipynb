# %%
pelicula_fav = "Interestelar"
anio = 2014
vista = True

print(f"Mi película favorita es {pelicula_fav} ({anio}).")
print(f"¿La he visto? {vista}")
# Out:
# Mi película favorita es Interestelar (2014).
# ¿La he visto? True
